# %% [markdown]
# # TODO Present the data managmenent capabilities by presenting a Cognitive API
# # classifier that was trained on the entire dataset. And not only 128 images as
# # in the Cognitive API section.
# Auricularia_auricula-judae: edible
# Xerocomellus_chrysenteron: edible
# Cylindrobasidium_laeve: poisonous
# Fomes_fomentarius: inedible
# Fomitopsis pinicola: inedible
# Ganoderma applanatum: inedible
# Ganoderma_pfeifferi: inedible
# Hypholoma_fasciculare: poisonous
# Laccaria_laccata: edible
# Mycena_galericulata: inedible
# Pluteus_cervinus: edible
# Psathyrella_candolleana: edible
# Trametes_versicolor: inedible
# Tricholoma_scalpturatum: edible
# Armillaria_lutea: edible
# Byssomerulius_corium: inedible
# Coprinellus_micaceus: edible

# %%
from azure.storage.blob import ContainerClient
container = ContainerClient.from_container_url(
    "https://storageaccountmay23.blob.core.windows.net/epita"
)
blobs_list = container.list_blobs()
for blob in blobs_list:
    print(blob.name)
# Out:
# out
# out/62c76870-3f02-4ae9-acb0-7476189e4a6b
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/ANB2016-9177939_BklUi8V50.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/ANB2016-9177939_ry8j8V50.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/ANB2016-9178737_H1A2LtQyg.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/ANB2016-9178737_HkxRnUFQkx.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/BEC2017-9210022_BJLYpgQqW.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/BEC2017-9210022_BJlTmpx75-.JPG
# out/c02c6bb4-f67b-454e-bf56-7352b0e6f398/images/10000_Abortiporus_biennis/BEC2017-9210022_HklUF6lQcZ.JPG
# ...
